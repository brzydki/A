# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
data = pd.read_excel("datatest.xlsx")

# %%
data
# Out:
#                                   А         1        2         3         4  \
# 0              Российская Федерация   51772.2  84423.3   76738.2   45501.8
# 1    Центральный  федеральный округ       NaN      NaN       NaN       NaN
# 2             Белгородская область    46397.6  39723.4   51828.4   45739.7
# 3                  Брянская область   36591.3  32721.6   39522.2     36407
# 4              Владимирская область   39564.1        -   41063.1   39425.4
# ..                              ...       ...      ...       ...       ...
# 387                Амурская область   77053.1  80787.6   83971.8   76642.2
# 388             Магаданская область  160125.3        -  156679.3  160696.7
# 389             Сахалинская область  143124.2        -  115704.4  143611.8
# 390    Еврейская автономная область   67606.3      …1)   72647.5   67284.8
# 391      Чукотский автономный округ  192414.2        -       …1)  192255.3
#
#          5      6      7      8         9   Год  Месяц
# 0     99.9  162.9  148.1   87.8   51820.0  2023      3
# 1      NaN    NaN    NaN    NaN       NaN  2023      3
# 2    114.8   98.3  128.3  113.2   40401.0  2023      3
# 3    108.8   97.3  117.5  108.2   33636.0  2023      3
# 4    107.7      -  111.8  107.4   36725.0  2023      3
# ..     ...    ...    ...    ...       ...   ...    ...
# 387  118.6  124.3  129.3    118   64968.0  2024      6
# 388  134.2      -  131.3  134.7  119312.0  2024      6
# 389  138.5      -  111.9  138.9  103361.0  2024      6
# 390  115.6    …1)  124.2    115   58491.0  2024      6
# 391  125.0      -    …1)  124.9  153982.0  2024      6
#
# [392 rows x 12 columns]

# %%
data = data[data.iloc[:, 9].notna() & (data.iloc[:, 9] != '')]
sns.pairplot(data)
# Out:
# C:\Users\Vladimir\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data = pd.get_dummies(data, columns=[data.columns[0]])

# %%
data
# Out:
#             1        2         3         4      5      6      7      8  \
# 0     51772.2  84423.3   76738.2   45501.8   99.9  162.9  148.1   87.8
# 2     46397.6  39723.4   51828.4   45739.7  114.8   98.3  128.3  113.2
# 3     36591.3  32721.6   39522.2     36407  108.8   97.3  117.5  108.2
# 4     39564.1        -   41063.1   39425.4  107.7      -  111.8  107.4
# 5     42303.8    53357   41486.5   42325.2  110.5  139.3  108.3  110.5
# ..        ...      ...       ...       ...    ...    ...    ...    ...
# 387   77053.1  80787.6   83971.8   76642.2  118.6  124.3  129.3    118
# 388  160125.3        -  156679.3  160696.7  134.2      -  131.3  134.7
# 389  143124.2        -  115704.4  143611.8  138.5      -  111.9  138.9
# 390   67606.3      …1)   72647.5   67284.8  115.6    …1)  124.2    115
# 391  192414.2        -       …1)  192255.3  125.0      -    …1)  124.9
#
#             9   Год  ...  А_Ханты-Мансийский авт. округ-Югра  \
# 0     51820.0  2023  ...                               False
# 2     40401.0  2023  ...                               False
# 3     33636.0  2023  ...                               False
# 4     36725.0  2023  ...                               False
# 5     38293.0  2023  ...                               False
# ..        ...   ...  ...                                 ...
# 387   64968.0  2024  ...                               False
# 388  119312.0  2024  ...                               False
# 389  103361.0  2024  ...                               False
# 390   58491.0  2024  ...                               False
# 391  153982.0  2024  ...                               False
#
#      А_Челябинская область  А_Чеченская Республика  \
# 0                    False                   False
# 2                    False                   False
# 3                    False                   False
# 4                    False                   False
# 5                    False                   False
# ..                     ...                     ...
# 387                  False                   False
# 388                  False                   False
# 389                  False                   False
# 390                  False                   False
# 391                  False                   False
#
#      А_Чувашская Республика - Чувашия  А_Чукотский автономный округ  \
# 0                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                         False
# 5                               False                         False
# ..                                ...                           ...
# 387                             False                         False
# 388                             False                         False
# 389                             False                         False
# 390                             False                         False
# 391                             False                          True
#
#      А_Ямало-Ненецкий авт. округ  А_Ярославская область  А_г. Севастополь  \
# 0                          False                  False             False
# 2                          False                  False             False
# 3                          False                  False             False
# 4                          False                  False             False
# 5                          False                  False             False
# ..                           ...                    ...               ...
# 387                        False                  False             False
# 388                        False                  False             False
# 389                        False                  False             False
# 390                        False                  False             False
# 391                        False                  False             False
#
#      А_г.Москва  А_г.Санкт-Петербург
# 0         False                 False
# 2         False                 False
# 3         False                 False
# 4         False                 False
# 5         False                 False
# ..          ...                   ...
# 387       False                 False
# 388       False                 False
# 389       False                 False
# 390       False                 False
# 391       False                 False
#
# [344 rows x 97 columns]

# %%
X=X = data.iloc[:, 9:]
y = data.iloc[:, 8]

# %%
X
# Out:
#       Год  Месяц  А_Алтайский край  А_Амурская область  \
# 0    2023      3             False               False
# 2    2023      3             False               False
# 3    2023      3             False               False
# 4    2023      3             False               False
# 5    2023      3             False               False
# ..    ...    ...               ...                 ...
# 387  2024      6             False                True
# 388  2024      6             False               False
# 389  2024      6             False               False
# 390  2024      6             False               False
# 391  2024      6             False               False
#
#      А_Архангельская область без авт. округа  А_Астраханская область  \
# 0                                      False                   False
# 2                                      False                   False
# 3                                      False                   False
# 4                                      False                   False
# 5                                      False                   False
# ..                                       ...                     ...
# 387                                    False                   False
# 388                                    False                   False
# 389                                    False                   False
# 390                                    False                   False
# 391                                    False                   False
#
#      А_Белгородская область   А_Брянская область  А_Владимирская область  \
# 0                      False               False                   False
# 2                       True               False                   False
# 3                      False                True                   False
# 4                      False               False                    True
# 5                      False               False                   False
# ..                       ...                 ...                     ...
# 387                    False               False                   False
# 388                    False               False                   False
# 389                    False               False                   False
# 390                    False               False                   False
# 391                    False               False                   False
#
#      А_Волгоградская область  ...  А_Ханты-Мансийский авт. округ-Югра  \
# 0                      False  ...                               False
# 2                      False  ...                               False
# 3                      False  ...                               False
# 4                      False  ...                               False
# 5                      False  ...                               False
# ..                       ...  ...                                 ...
# 387                    False  ...                               False
# 388                    False  ...                               False
# 389                    False  ...                               False
# 390                    False  ...                               False
# 391                    False  ...                               False
#
#      А_Челябинская область  А_Чеченская Республика  \
# 0                    False                   False
# 2                    False                   False
# 3                    False                   False
# 4                    False                   False
# 5                    False                   False
# ..                     ...                     ...
# 387                  False                   False
# 388                  False                   False
# 389                  False                   False
# 390                  False                   False
# 391                  False                   False
#
#      А_Чувашская Республика - Чувашия  А_Чукотский автономный округ  \
# 0                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                         False
# 5                               False                         False
# ..                                ...                           ...
# 387                             False                         False
# 388                             False                         False
# 389                             False                         False
# 390                             False                         False
# 391                             False                          True
#
#      А_Ямало-Ненецкий авт. округ  А_Ярославская область  А_г. Севастополь  \
# 0                          False                  False             False
# 2                          False                  False             False
# 3                          False                  False             False
# 4                          False                  False             False
# 5                          False                  False             False
# ..                           ...                    ...               ...
# 387                        False                  False             False
# 388                        False                  False             False
# 389                        False                  False             False
# 390                        False                  False             False
# 391                        False                  False             False
#
#      А_г.Москва  А_г.Санкт-Петербург
# 0         False                 False
# 2         False                 False
# 3         False                 False
# 4         False                 False
# 5         False                 False
# ..          ...                   ...
# 387       False                 False
# 388       False                 False
# 389       False                 False
# 390       False                 False
# 391       False                 False
#
# [344 rows x 88 columns]

# %%
y
# Out:
# 0       51820.0
# 2       40401.0
# 3       33636.0
# 4       36725.0
# 5       38293.0
#          ...
# 387     64968.0
# 388    119312.0
# 389    103361.0
# 390     58491.0
# 391    153982.0
# Name: 9, Length: 344, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("\nКачество модели:")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Качество модели:
# Mean Absolute Error (MAE): 1486.9519497838403
# Mean Squared Error (MSE): 5781603.762933122
# Root Mean Squared Error (RMSE): 2404.496571620164

# %%
model.coef_
# Out:
# array([  8084.11741846,    897.85338468, -16524.40853236,   6448.59146764,
#          9153.84146764, -13511.15853236,  -6926.65853236, -13833.65853236,
#        -10444.65853236, -15928.40853236,   -893.84982313,  -9293.15853236,
#           800.09146764,   3203.09146764, -20038.65853236,   8489.97853889,
#        -22574.40853236,  -8988.90853236,  -4773.8347431 ,  40653.1652569 ,
#        -21369.35479445,   2652.59146764, -12080.15853236, -13731.31565496,
#         -9277.15853236,  15526.34146764,  -9216.90853236,  -8139.98232163,
#          1624.34146764,  -8009.15853236,  58785.49859024,  12188.09146764,
#         32697.59146764,  58927.34146764,  -6794.8347431 ,  -6958.15853236,
#          1157.34146764,  -8439.90853236,  -7994.90853236, -12814.15853236,
#        -15178.90853236,  -3423.40853236,   5138.35101171, -14635.40853236,
#        -13588.02146111,  -7935.40853236,  -6831.31565496,  -3098.90853236,
#        -22668.40853236, -24202.18860938, -19301.65853236,   2734.34146764,
#         14484.87106306, -16785.90853236, -13325.24731861, -14653.90853236,
#         34678.09146764, -21267.15853236,   -684.90853236,  -2998.65853236,
#         -4154.18860938,   6163.64520555, -11699.65853236,  -8551.65853236,
#         -7290.68860938, -13863.02146111,  44533.34146764,   3066.59146764,
#        -12433.65853236, -16972.65853236, -15774.31565496,  -8175.98232163,
#          -241.65853236,  -4747.90853236,   6872.09146764,  -8269.40853236,
#        -13706.90853236,   5695.49859024,  36650.09146764,  -5156.90853236,
#        -22447.65853236, -12279.15853236,  85517.87106306,  81705.84146764,
#         -7130.40853236, -11022.40853236,  48472.84146764,  25034.09146764])

# %%
sns.pairplot(data)
# Out:
# KeyboardInterrupt

# %%
data
